# %% [markdown]
# <p>Nombre estudiante: Antonella Caroca Sanhueza</p>
# <h3>Cómo usar el proyecto?</h3>
# <br>
# <h6>Una vez ejecutado el jupyter notebook, el usuario debe ingresar el nombre de una comuna de la región metropolitana
# de Santiago. Luego de unos segundos, el programa entregará la siguiente información sobre los combustibles de dicha comuna:</h6>
# <br>
# <ul>
# <li>Comuna: </li>
# <li>Fecha y hora de actualización: </li>
# <li>Horario de atención:</li>
# <li>Nombre distribuidor:</li>
# <li>Razón Social: </li>
# <li>Dirección:</li>
# <li>gasolina 93:</li>
# <li>gasolina 95:</li>
# <li>gasolina 97:</li>
# <li>petroleo diesel:</li>
# <li>efectivo:</li>
# <li>cheque:</li>
# <li>tarjetas bancarias:</li>
# <li>tarjetas grandes tiendas:</li>
# <li>tienda:</li>
# <li>farmacia: </li>
# <li>mantencion:</li>
# <li>autoservicio:</li>
# </ul>
# <h6>El enfoque de este proyecto está en presentar una comparación entre los precios de los distintos tipos de combustible vehicular
# de una comuna seleccionada por el usuario. Es por esto que se señalan conclusiones respecto a los valores de los combustibles.</h6>
# <br>
# <h6>Módulos ocupados en el desarrollo de este proyecto:</h6>
# <ul>
# <li>requests</li>
# </ul>
# <h6>Para finalizar, el proyecto entrega un registro de toda la información de una comuna en un archivo txt ("archivo.txt"). En caso que
# se pierda la conexión de internet, se podrá contar con este registro. Dicho archivo se sobreescribe cada vez que se ejecuta el proyecto.
# </h6>

# %%
import requests

token = "hISHc9TmCE"
url = "http://api.cne.cl/v3/combustibles/vehicular/estaciones"
comuna = input('Ingrese la comuna: ').title()

res = requests.get(f"{url}?token={token}")
res_json = res.json()

archivo = open("archivo.txt", "w")

lista_precio = []
barato = []
caro = []
gas_93 = []
gas_95 = []
gas_97 = []
diesel = []
glp = []
gnc = []

for d in res_json['data']:
    if d['id_region']=='13' and d['nombre_comuna']==comuna:
        print('Comuna:', d['nombre_comuna'])
        archivo.write("\n")
        archivo.write(f"Comuna: {d['nombre_comuna']}"+ "\n")
        print('\tFecha actualización:', d['fecha_hora_actualizacion'])
        archivo.write(f"\tFecha y hora de actualización: {d['fecha_hora_actualizacion']}"+ "\n")
        print('\tHorario de atención:', d['horario_atencion'])
        archivo.write(f"\tHorario de atención: {d['horario_atencion']}"+ "\n")
        print('\tNombre distribuidor:', d['distribuidor']['nombre'])
        archivo.write(f"\tNombre distribuidor: {d['distribuidor']['nombre']}"+ "\n")
        print('\tRazón Social:', d['razon_social'])
        archivo.write(f"\tRazón Social: {d['razon_social']}"+ "\n")
        print('\tDirección:', d['direccion_calle'], d['direccion_numero'])
        archivo.write(f"\tDirección: {d['direccion_calle']} {d['direccion_numero']}"+ "\n")
        for nombre, valor in (d['precios']).items():
            if nombre == 'gasolina 93':
                gas_93.append((nombre, valor))
            elif nombre == 'gasolina 95':
                gas_95.append((nombre, valor))
            elif nombre == 'gasolina 97':
                gas_97.append((nombre, valor))
            elif nombre == 'petroleo diesel':
                diesel.append((nombre, valor))
            elif nombre == 'glp vehicular':
                glp.append((nombre, valor))
            elif nombre == 'gnc':
                gnc.append((nombre, valor))
            print(nombre, ':', valor)
            archivo.write(f"{nombre}: {valor}"+ "\n")
            lista_precio.append(valor)
            lista_precio.sort()
            if valor==lista_precio[0]:
                barato.append((valor, nombre))
                barato.sort()
            elif valor ==lista_precio[-1]:
                caro.append((valor,nombre))
                caro.sort()
        for met, res in (d['metodos_de_pago']).items():
            if res == False:
                res = 'No'
            else:
                res = 'Sí'
            print('\tMétodos de pago:', met, res)
            archivo.write(f"\t{met}: {res}"+ "\n")
        for s, servicio in (d['servicios']).items():
            if servicio == False:
                servicio = 'No'
            else:
                servicio = 'Sí'
            print('\tServicios:', s, servicio)
            archivo.write(f"\t{s}: {servicio}"+ "\n")
           
        print()

gas_93.sort()
gas_95.sort()
gas_97.sort()
diesel.sort()
glp.sort()
gnc.sort()

try:
# conclusiones
    archivo.write("\n")
    print("=====================================================================================================")
    archivo.write("====================================================================================================="+ "\n")
    print('Basado en la información consultada, se puede concluir que: \n')
    archivo.write("Basado en la información consultada, se puede concluir que:" +"\n")
    print(f"\tEl combustible más barto de la comuna de {comuna} es {(barato[0][1])} y vale: {lista_precio[0]} pesos por litro.")
    archivo.write(f"El combustible más barto de la comuna de {comuna} es {(barato[0][1])} y vale: {lista_precio[0]} pesos por litro." +"\n")
    print(f"\tEl combustible más caro de la comuna de {comuna} es {caro[-1][-1]} y vale: {lista_precio[-1]} pesos por litro.")
    archivo.write(f"El combustible más caro de la comuna de {comuna} es {caro[-1][-1]} y vale: {lista_precio[-1]} pesos por litro." +"\n")
    print(f"\tLa diferencia entre el combustible más barto y más caro es: {lista_precio[-1] - lista_precio[0]} pesos.")
    archivo.write(f"La diferencia entre el combustible más barto y más caro es: {lista_precio[-1] - lista_precio[0]} pesos." +"\n")
    print()
    archivo.write("\n")
    print("Comparación de precios entre tipos de combustibles: \n")
    archivo.write("Comparación de precios entre tipos de combustibles: "+"\n")
    print(f"\tGasolina 93 más barato: {gas_93[0][1]}. Más caro: {gas_93[-1][-1]}. Hay una diferencia de: {(gas_93[-1][-1])-(gas_93[0][1])}")
    archivo.write(f"\tGasolina 93 más barato: {gas_93[0][1]}. Más caro: {gas_93[-1][-1]}. Hay una diferencia de: {(gas_93[-1][-1])-(gas_93[0][1])}"+"\n")
    print(f"\tGasolina 95 más barato: {gas_95[0][1]}. Más caro: {gas_95[-1][-1]}. Hay una diferencia de: {(gas_95[-1][-1])-(gas_95[0][1])}")
    archivo.write(f"\tGasolina 95 más barato: {gas_95[0][1]}. Más caro: {gas_95[-1][-1]}. Hay una diferencia de: {(gas_95[-1][-1])-(gas_95[0][1])}"+"\n")
    print(f"\tGasolina 97 más barato: {gas_97[0][1]}. Más caro: {gas_97[-1][-1]}. Hay una diferencia de: {(gas_97[-1][-1])-(gas_97[0][1])}")
    archivo.write(f"\tGasolina 97 más barato: {gas_97[0][1]}. Más caro: {gas_97[-1][-1]}. Hay una diferencia de: {(gas_97[-1][-1])-(gas_97[0][1])}"+"\n")
    print(f"\tPetróleo diesel más barato: {diesel[0][1]}. Más caro: {diesel[-1][-1]}. Hay una diferencia de: {(diesel[-1][-1])-(diesel[0][1])}")
    archivo.write(f"\tPetróleo diesel más barato: {diesel[0][1]}. Más caro: {diesel[-1][-1]}. Hay una diferencia de: {(diesel[-1][-1])-(diesel[0][1])}"+"\n")
    print(f"\tGlp más barato: {glp[0][1]}. Más caro: {glp[-1][-1]}. Hay una diferencia de: {(glp[-1][-1])-(glp[0][1])}")
    archivo.write(f"\tGlp más barato: {glp[0][1]}. Más caro: {glp[-1][-1]}. Hay una diferencia de: {(glp[-1][-1])-(glp[0][1])}"+"\n")

    try:
        print(f"\tGnc más barato: {gnc [0][1]}. Más caro: es {gnc[-1][-1]}. Hay una diferencia de: {(gnc[-1][-1])-(gnc[0][1])}")
        archivo.write(f"\tGnc más barato: {gnc [0][1]}. Más caro: es {gnc[-1][-1]}. Hay una diferencia de: {(gnc[-1][-1])-(gnc[0][1])}"+"\n")
    except:
        print("\tNo se registra combustible gnc")
        archivo.write("\tNo se registra combustible gnc"+"\n")

except:
    print("nombre comuna no valida")
    archivo.write("nombre comuna no valida"+"\n")

archivo.close()
# Out:
# Ingrese la comuna: la florida
# Comuna: La Florida
# 	Fecha actualización: 2019-09-05 21:41:07
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Copec
# 	Razón Social: 772156405
# 	Dirección: Avenida La Florida  Trinidad 9871
# gasolina 93 : 789
# gasolina 97 : 887
# petroleo diesel : 599
# gasolina 95 : 836
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque No
# 	Métodos de pago: tarjetas bancarias Sí
# 	Métodos de pago: tarjetas grandes tiendas Sí
# 	Servicios: tienda Sí
# 	Servicios: farmacia Sí
# 	Servicios: mantencion Sí
# 	Servicios: autoservicio Sí
#
# Comuna: La Florida
# 	Fecha actualización: 2019-09-05 10:14:50
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Copec
# 	Razón Social: COMERCIAL Y SERVICIOS P&P LTDA.
# 	Dirección: Avenida La Florida 11215
# gasolina 93 : 789
# gasolina 97 : 886
# petroleo diesel : 599
# gasolina 95 : 836
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque No
# 	Métodos de pago: tarjetas bancarias Sí
# 	Métodos de pago: tarjetas grandes tiendas Sí
# 	Servicios: tienda No
# 	Servicios: farmacia No
# 	Servicios: mantencion No
# 	Servicios: autoservicio No
#
# Comuna: La Florida
# 	Fecha actualización: 2019-09-05 11:31:27
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Copec
# 	Razón Social: Steffens y Compañia Ltda
# 	Dirección: Lía Aguirre 10
# gasolina 93 : 798
# gasolina 97 : 894
# petroleo diesel : 597
# gasolina 95 : 841
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque Sí
# 	Métodos de pago: tarjetas bancarias Sí
# 	Métodos de pago: tarjetas grandes tiendas Sí
# 	Servicios: tienda Sí
# 	Servicios: farmacia No
# 	Servicios: mantencion No
# 	Servicios: autoservicio No
#
# Comuna: La Florida
# 	Fecha actualización: 2019-09-05 10:41:37
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Copec
# 	Razón Social: Sociedad Comercial El Olivo Limitada
# 	Dirección: Trinidad  Bahía Catalina 1694
# gasolina 93 : 789
# gasolina 97 : 869
# petroleo diesel : 597
# gasolina 95 : 823
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque Sí
# 	Métodos de pago: tarjetas bancarias Sí
# 	Métodos de pago: tarjetas grandes tiendas Sí
# 	Servicios: tienda No
# 	Servicios: farmacia No
# 	Servicios: mantencion No
# 	Servicios: autoservicio Sí
#
# Comuna: La Florida
# 	Fecha actualización: 2019-09-05 07:12:24
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Copec
# 	Razón Social: --
# 	Dirección: Vicuña Mackenna Los Cóndores 8257
# gasolina 93 : 792
# gasolina 97 : 886
# petroleo diesel : 595
# gasolina 95 : 835
# 	Métodos de pago: efectivo No
# 	Métodos de pago: cheque No
# 	Métodos de pago: tarjetas bancarias No
# 	Métodos de pago: tarjetas grandes tiendas No
# 	Servicios: tienda No
# 	Servicios: farmacia No
# 	Servicios: mantencion No
# 	Servicios: autoservicio No
#
# Comuna: La Florida
# 	Fecha actualización: 2019-09-05 09:25:27
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Copec
# 	Razón Social: Comercial y servicios AVILSA Ltda
# 	Dirección: San José de la Estrella  Santa Raquel 1301
# gasolina 93 : 789
# gasolina 97 : 869
# petroleo diesel : 597
# gasolina 95 : 823
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque No
# 	Métodos de pago: tarjetas bancarias Sí
# 	Métodos de pago: tarjetas grandes tiendas Sí
# 	Servicios: tienda No
# 	Servicios: farmacia No
# 	Servicios: mantencion No
# 	Servicios: autoservicio No
#
# Comuna: La Florida
# 	Fecha actualización: 2019-09-05 09:42:46
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Copec
# 	Razón Social: ANTONIO VILLEGAS SANTANA
# 	Dirección: Avenida Trinidad 1300
# gasolina 93 : 789
# gasolina 97 : 869
# petroleo diesel : 597
# gasolina 95 : 823
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque Sí
# 	Métodos de pago: tarjetas bancarias Sí
# 	Métodos de pago: tarjetas grandes tiendas Sí
# 	Servicios: tienda No
# 	Servicios: farmacia No
# 	Servicios: mantencion Sí
# 	Servicios: autoservicio No
#
# Comuna: La Florida
# 	Fecha actualización: 2019-09-05 09:32:28
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Copec
# 	Razón Social: Comercial y Servicios San Damián Limitada
# 	Dirección: Américo Vespucio  Sótero del Río 9150
# gasolina 93 : 784
# gasolina 97 : 855
# petroleo diesel : 584
# gasolina 95 : 818
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque Sí
# 	Métodos de pago: tarjetas bancarias Sí
# 	Métodos de pago: tarjetas grandes tiendas Sí
# 	Servicios: tienda Sí
# 	Servicios: farmacia No
# 	Servicios: mantencion Sí
# 	Servicios: autoservicio No
#
# Comuna: La Florida
# 	Fecha actualización: 2019-09-05 15:20:08
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Copec
# 	Razón Social: Administradora de ventas al detalle ltda.
# 	Dirección: Avenida La Florida 7165
# gasolina 93 : 789
# gasolina 97 : 883
# petroleo diesel : 588
# gnc : 529
# glp vehicular : 269
# gasolina 95 : 830
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque No
# 	Métodos de pago: tarjetas bancarias Sí
# 	Métodos de pago: tarjetas grandes tiendas Sí
# 	Servicios: tienda Sí
# 	Servicios: farmacia No
# 	Servicios: mantencion No
# 	Servicios: autoservicio Sí
#
# Comuna: La Florida
# 	Fecha actualización: 2019-08-16 10:11:00
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Lipigas
# 	Razón Social: LIZKA WILMA RIVAS CIFUENTE
# 	Dirección: Mirador Azul 900
# glp vehicular : 240
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque No
# 	Métodos de pago: tarjetas bancarias No
# 	Métodos de pago: tarjetas grandes tiendas No
# 	Servicios: tienda No
# 	Servicios: farmacia No
# 	Servicios: mantencion No
# 	Servicios: autoservicio No
#
# Comuna: La Florida
# 	Fecha actualización: 2019-08-29 14:49:44
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Ecogreen ltda.
# 	Razón Social: Administradora de Servicios Ecogreen Ltda. / R.U.T. : 76.291.532-4
# 	Dirección: REAL ALICANTE 6698
# gasolina 93 : 792
# gasolina 97 : 892
# petroleo diesel : 589
# glp vehicular : 269
# gasolina 95 : 835
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque Sí
# 	Métodos de pago: tarjetas bancarias Sí
# 	Métodos de pago: tarjetas grandes tiendas No
# 	Servicios: tienda No
# 	Servicios: farmacia No
# 	Servicios: mantencion Sí
# 	Servicios: autoservicio No
#
# Comuna: La Florida
# 	Fecha actualización: 2019-09-05 08:27:53
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Petrobras
# 	Razón Social: PETROBRAS CHILE RED LTDA
# 	Dirección: Rojas Magallanes 1459
# gasolina 93 : 787
# gasolina 97 : 885
# petroleo diesel : 597
# gasolina 95 : 834
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque Sí
# 	Métodos de pago: tarjetas bancarias Sí
# 	Métodos de pago: tarjetas grandes tiendas Sí
# 	Servicios: tienda Sí
# 	Servicios: farmacia No
# 	Servicios: mantencion No
# 	Servicios: autoservicio Sí
#
# Comuna: La Florida
# 	Fecha actualización: 2019-09-05 07:57:16
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Petrobras
# 	Razón Social: Petrobras Chile Red Ltda.
# 	Dirección: Vicuña Mackenna 9815
# gasolina 93 : 787
# gasolina 97 : 867
# petroleo diesel : 595
# gasolina 95 : 821
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque Sí
# 	Métodos de pago: tarjetas bancarias Sí
# 	Métodos de pago: tarjetas grandes tiendas Sí
# 	Servicios: tienda Sí
# 	Servicios: farmacia Sí
# 	Servicios: mantencion No
# 	Servicios: autoservicio Sí
#
# Comuna: La Florida
# 	Fecha actualización: 2019-09-05 08:05:16
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Petrobras
# 	Razón Social: PETROBRAS CHILE RED LTDA
# 	Dirección: Vicuña Mackenna 7589
# gasolina 93 : 794
# gasolina 97 : 890
# petroleo diesel : 593
# gasolina 95 : 837
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque Sí
# 	Métodos de pago: tarjetas bancarias Sí
# 	Métodos de pago: tarjetas grandes tiendas Sí
# 	Servicios: tienda Sí
# 	Servicios: farmacia No
# 	Servicios: mantencion No
# 	Servicios: autoservicio Sí
#
# Comuna: La Florida
# 	Fecha actualización: 2019-09-05 17:19:33
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Petrobras
# 	Razón Social: Juan Bautista Bustamante Hurtado
# 	Dirección: Américo Vespucio 9077
# gasolina 93 : 782
# gasolina 97 : 853
# petroleo diesel : 582
# gasolina 95 : 816
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque No
# 	Métodos de pago: tarjetas bancarias No
# 	Métodos de pago: tarjetas grandes tiendas No
# 	Servicios: tienda No
# 	Servicios: farmacia No
# 	Servicios: mantencion No
# 	Servicios: autoservicio No
#
# Comuna: La Florida
# 	Fecha actualización: 2019-09-05 15:12:08
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Shell
# 	Razón Social: GONZALEZ,GONZALEZ Y CIA LTDA
# 	Dirección: Walker Martinez 1940
# gasolina 93 : 789
# gasolina 97 : 883
# petroleo diesel : 588
# gasolina 95 : 830
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque No
# 	Métodos de pago: tarjetas bancarias Sí
# 	Métodos de pago: tarjetas grandes tiendas No
# 	Servicios: tienda Sí
# 	Servicios: farmacia No
# 	Servicios: mantencion Sí
# 	Servicios: autoservicio Sí
#
# Comuna: La Florida
# 	Fecha actualización: 2019-09-05 15:07:29
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Shell
# 	Razón Social: gonzalez gonzalez y cia ltda
# 	Dirección: Avda. La Florida 9801
# gasolina 93 : 789
# gasolina 97 : 887
# petroleo diesel : 599
# gasolina 95 : 836
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque No
# 	Métodos de pago: tarjetas bancarias Sí
# 	Métodos de pago: tarjetas grandes tiendas No
# 	Servicios: tienda Sí
# 	Servicios: farmacia No
# 	Servicios: mantencion Sí
# 	Servicios: autoservicio No
#
# Comuna: La Florida
# 	Fecha actualización: 2019-09-05 10:03:15
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Shell
# 	Razón Social: Jaime de la Fuente Infanta
# 	Dirección: Colombia 7111
# gasolina 93 : 795
# gasolina 97 : 892
# petroleo diesel : 595
# gasolina 95 : 836
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque No
# 	Métodos de pago: tarjetas bancarias Sí
# 	Métodos de pago: tarjetas grandes tiendas No
# 	Servicios: tienda Sí
# 	Servicios: farmacia No
# 	Servicios: mantencion No
# 	Servicios: autoservicio No
#
# Comuna: La Florida
# 	Fecha actualización: 2019-09-05 15:22:42
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Shell
# 	Razón Social: Estacion de Servicio de Combustible
# 	Dirección: Avenida Diego Portales 786
# gasolina 93 : 780
# gasolina 97 : 884
# petroleo diesel : 580
# gasolina 95 : 790
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque No
# 	Métodos de pago: tarjetas bancarias Sí
# 	Métodos de pago: tarjetas grandes tiendas No
# 	Servicios: tienda No
# 	Servicios: farmacia No
# 	Servicios: mantencion No
# 	Servicios: autoservicio No
#
# Comuna: La Florida
# 	Fecha actualización: 2019-09-05 10:21:44
# 	Horario de atención: 24 horas
# 	Nombre distribuidor: Shell
# 	Razón Social: Inversiones Enex S.A.
# 	Dirección: Av. Vicuña Mackenna 9840
# gasolina 93 : 789
# gasolina 97 : 869
# petroleo diesel : 597
# gnc : 529
# glp vehicular : 357
# gasolina 95 : 823
# 	Métodos de pago: efectivo Sí
# 	Métodos de pago: cheque No
# 	Métodos de pago: tarjetas bancarias Sí
# 	Métodos de pago: tarjetas grandes tiendas Sí
# 	Servicios: tienda Sí
# 	Servicios: farmacia No
# 	Servicios: mantencion No
# 	Servicios: autoservicio No
#
# =====================================================================================================
# Basado en la información consultada, se puede concluir que:
#
# 	El combustible más barto de la comuna de La Florida es glp vehicular y vale: 240 pesos por litro.
# 	El combustible más caro de la comuna de La Florida es gasolina 97 y vale: 894 pesos por litro.
# 	La diferencia entre el combustible más barto y más caro es: 654 pesos.
#
# Comparación de precios entre tipos de combustibles:
#
# 	Gasolina 93 más barato: 780. Más caro: 798. Hay una diferencia de: 18
# 	Gasolina 95 más barato: 790. Más caro: 841. Hay una diferencia de: 51
# 	Gasolina 97 más barato: 853. Más caro: 894. Hay una diferencia de: 41
# 	Petróleo diesel más barato: 580. Más caro: 599. Hay una diferencia de: 19
# 	Glp más barato: 240. Más caro: 357. Hay una diferencia de: 117
# 	Gnc más barato: 529. Más caro: es 529. Hay una diferencia de: 0
